# %%
import matplotlib.pyplot as plt

# %%
# analyze matrix dimension
matrix_dim_list = [200, 400, 800, 1600, 3200, 6400, 10000, 20000, 40000]
runtime_1d_list = [0.00015, 0.00086, 0.00604, 0.05750, 0.83716, 8.29887, 35.08759, 263.15892, 2147.60897]
runtime_2d_list = [0.00018, 0.00068, 0.00604, 0.02310, 0.16824, 1.21481, 4.62339, 37.36907, 301.32677]

fig = plt.figure(figsize=(15,7))
plt.plot(matrix_dim_list, runtime_1d_list, 'bs-', label="GPU-1D")
plt.plot(matrix_dim_list, runtime_2d_list, 'g^-', label="GPU-2D")
plt.xlabel("matrix dimesion")
plt.ylabel("running time/s")

runtime_cpu_list = [0.04594, 0.05549, 0.06267, 0.07679, 0.84337, 4.61865, 5.58258, 26.16758, 108.76481]
plt.plot(matrix_dim_list, runtime_cpu_list, 'r--', label="CPU")

plt.legend()
plt.show()

# %%
# analyze block size
block_size_list1 = [4, 8, 16, 32, 64, 128, 256, 512, 1024]
runtime_1d_list = [2.58747, 2.10253, 1.87324, 0.90652 ,0.81281 ,0.76258, 0.72636, 0.69757, 0.37377]
block_size_list2 = [4, 8, 16, 32]
runtime_2d_list = [0.84436, 0.29081, 0.18966, 0.15245]

fig = plt.figure(figsize=(15,7))
plt.plot(block_size_list1, runtime_1d_list, 'bs-', label="GPU-1D")
plt.plot(block_size_list2, runtime_2d_list, 'g^-', label="GPU-2D")
plt.xlabel("block size")
plt.ylabel("running time/s")

# runtime_cpu_list = []
# plt.plot(matrix_dim_list, runtime_cpu_list, 'r--', label="CPU")

plt.legend()
plt.show()
